# %% [markdown]
# <a href="https://colab.research.google.com/github/Kapil-g1825/GitDemo/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=["apple","banana","Grapes","Orange"]
list2=["potato","tomato","cauliflower"]
list3=[1,2,3]
list4=[6,7,8]
print(list1+list2+list3)
# Out:
# ['apple', 'banana', 'Grapes', 'Orange', 'potato', 'tomato', 'cauliflower', 1, 2, 3]

# %%
list1.append(list2)
print(list1)
# Out:
# ['apple', 'banana', 'Grapes', 'Orange', ['potato', 'tomato', 'cauliflower']]

# %%
list1[-1].append("mango")
print(list1)
# Out:
# ['apple', 'banana', 'Grapes', 'Orange', ['potato', 'tomato', 'cauliflower', 'mango']]

# %%
list1.insert(3,"pear")
print(list1)
# Out:
# ['apple', 'banana', 'Grapes', 'pear', 'grapes', 'Orange']

# %% [markdown]
# Tuple start:-

# %%
t1=(1,2,3)
t2=(4,5,6)
print(t1+t2)


# lst=list(t1)
# lst.remove(2)
# t1 = tuple(lst)
# print(t1)

# %% [markdown]
# Sets:-

# %%
fruit={"orange","apple","banana","grapes"}
print(fruit)
type(fruit)

fruit.add("lemon")
print(fruit)

fruit.remove("banana")
print(fruit)

fruit.pop()
print(fruit)

s1={1,2,3}
s2={"A","B","C"}
print(s1.union(s2))
# Out:
# {'banana', 'apple', 'grapes', 'orange'}
# {'apple', 'grapes', 'banana', 'lemon', 'orange'}
# {'apple', 'grapes', 'lemon', 'orange'}
# {'grapes', 'lemon', 'orange'}
# {1, 2, 3, 'B', 'A', 'C'}

# %% [markdown]
# Assignment 1:-Smart ATM Simulator.
# Develop a Python program that simulates the basic operations of an ATM.

# %% [markdown]
# Assignment 2 :-Student Result Analyzer.
# Develop a program to analyze marks obtained in five subjects.

# %%
marks1=int(input("Enter marks in subject 1:"))
marks2=int(input("Enter marks in subject 2:"))
marks3=int(input("Enter marks in subject 3:"))
marks4=int(input("Enter marks in subject 4:"))
marks5=int(input("Enter marks in subject 5:"))
total=marks1+marks2+marks3+marks4+marks5
percentage=(total/500)*100
print("Total marks:",total)
print("Percentage:",percentage)
if percentage>=90:
  print("Grade:A+")
elif percentage>=80:
  print("Grade:A")
elif percentage>=70:
  print("Grade:B")
elif percentage>=60:
  print("Grade:C")
elif percentage<60:
  print("Grade:D")
highest=max(marks1,marks2,marks3,marks4,marks5)
print("Highest marks:",highest)
lowest=min(marks1,marks2,marks3,marks4,marks5)
print("Lowest marks:",lowest)
# Out:
# Enter marks in subject 1:67
# Enter marks in subject 2:98
# Enter marks in subject 3:70
# Enter marks in subject 4:80
# Enter marks in subject 5:56
# Total marks: 371
# Percentage: 74.2
# Grade:B
# Highest marks: 98
# Lowest marks: 56

# %% [markdown]
# Assignmenet 4- Password strength checker.
# Determine whether a password is weak, medium, or strong.

# %%
password=input("Enter Your password:")

has_upper = False
has_lower = False
has_digit = False
has_special_character = False

for char in password:
  if char.isupper():
    has_upper = True
  elif char.islower():
    has_lower = True
  elif char.isdigit():
    has_digit = True
  elif not char.isalnum():
    has_special_character = True

length = len(password)>=8
count=0
if length:
  count+=1
if has_upper:
  count+=1
if has_lower:
  count+=1
if has_digit:
  count+=1
if has_special_character:
  count+=1

if count<=2:
  print("Weak")
elif count==3:
  print("Medium")
else:
  print("Hard")
# Out:
# Enter Your password:Kapil88
# Medium

# %% [markdown]
# Assignment 7:-Employee Salary calculator

# %%
employees=[]
n=int(input("Enter no of employees:"))
for i in range(n):
  print("\n Enter the details of Employee",i+1)
  name = input("Enter Employee Name: ")
  basic_salary = float(input("Enter Basic Salary: "))

  hra = 0.20 * basic_salary
  da = 0.10 * basic_salary
  gross_salary = basic_salary + hra + da

  employee = {
        "Name": name,
        "Basic Salary": basic_salary,
        "HRA": hra,
        "DA": da,
        "Gross Salary": gross_salary
  }

  employees.append(employee)

# Display Salary Details

print("\n ---- Employee Salary Details ----")

for emp in employees:
    print("\n Employee Name :", emp["Name"])
    print("Basic Salary  :", emp["Basic Salary"])
    print("HRA (20%)     :", emp["HRA"])
    print("DA (10%)      :", emp["DA"])
    print("Gross Salary  :", emp["Gross Salary"])
# Out:
# Enter no of employees:2
#
#  Enter the details of Employee 1
# Enter Employee Name: kapil
# Enter Basic Salary: 40000
#
#  Enter the details of Employee 2
# Enter Employee Name: raju
# Enter Basic Salary: 20000
#
# ===== Employee Salary Details =====
#
#  Employee Name : kapil
# Basic Salary  : 40000.0
# HRA (20%)     : 8000.0
# DA (10%)      : 4000.0
# Gross Salary  : 52000.0
#
#  Employee Name : raju
# Basic Salary  : 20000.0
# HRA (20%)     : 4000.0
# DA (10%)      : 2000.0
# Gross Salary  : 26000.0
